# %% [markdown]
# Curve Building, script 1 of the whole program, Chi Zhang

# %% [markdown]
# ## LIBOR, SOFR, and OIS curve loading

# %%
import pandas as pd
from math import exp
import matplotlib.pyplot as plt

# %%
LIBOR_data = pd.read_excel(r'C:\Users\Richard\Desktop\CurrentTerm\ISYE 8900\CurveFrcst-Using-ManifoldLrn\Data\WklyLIBOR.xlsx', sheet_name=None)
#LIBOR_data.keys()

# %%
for key in LIBOR_data:
    if key == '181102':
        LIBOR_zero = LIBOR_data[key]['Zero Rate'].to_frame(name = key)
        LIBOR_fwd = LIBOR_data[key]['Forward Rate'].to_frame(name = key)
    else:
        LIBOR_zero[key] = LIBOR_data[key]['Zero Rate']
        LIBOR_fwd[key] = LIBOR_data[key]['Forward Rate']
LIBOR_zero = LIBOR_zero.T
LIBOR_fwd = LIBOR_fwd.T

# %%
LIBOR_zero.columns = [3 * x for x in LIBOR_zero.columns]
LIBOR_zero
# each row is a sample (weekly), each row is a TTM (month)
# Out:
#             0         3         6         9         12        15        18   \
# 181102  2.61972  2.619717  2.774752  2.854803  2.932020  2.993549  3.041323
# 181109  2.64565  2.645652  2.787011  2.867154  2.943816  3.005727  3.053632
# 181116  2.67221  2.672210  2.769769  2.826092  2.880055  2.923548  2.956085
# 181123  2.71923  2.719228  2.806461  2.847600  2.890131  2.926382  2.953094
# 181130  2.76469  2.764687  2.833875  2.863447  2.895275  2.924858  2.945426
# ...         ...       ...       ...       ...       ...       ...       ...
# 201218  0.23895  0.238954  0.204002  0.193211  0.189512  0.194816  0.194454
# 201225  0.24339  0.243392  0.206935  0.197014  0.194525  0.199665  0.198346
# 210101  0.24162  0.241618  0.201545  0.190154  0.187536  0.191699  0.188848
# 210108  0.22743  0.227433  0.199779  0.192478  0.194271  0.199778  0.199790
# 210115  0.22642  0.226419  0.197089  0.189198  0.191038  0.194772  0.193626
#
#              21        24        27   ...       330       333       336  \
# 181102  3.071053  3.087379  3.101980  ...  3.325801  3.324922  3.323999
# 181109  3.080879  3.094139  3.106960  ...  3.274852  3.273796  3.272711
# 181116  2.967827  2.968256  2.971993  ...  3.198483  3.197749  3.196980
# 181123  2.966664  2.972859  2.978062  ...  3.182218  3.181558  3.180872
# 181130  2.945855  2.939158  2.936833  ...  3.126252  3.125658  3.125033
# ...          ...       ...       ...  ...       ...       ...       ...
# 201218  0.195933  0.204811  0.213640  ...  1.448889  1.450393  1.451783
# 201225  0.199559  0.204405  0.211510  ...  1.432860  1.434354  1.435735
# 210101  0.189832  0.196913  0.205120  ...  1.429827  1.431161  1.432391
# 210108  0.204842  0.214563  0.228545  ...  1.649823  1.651260  1.652583
# 210115  0.196899  0.204764  0.215537  ...  1.606894  1.608251  1.609519
#
#              339       342       345       348       351       354       357
# 181102  3.323051  3.322096  3.321101  3.320063  3.318991  3.317906  3.316760
# 181109  3.271608  3.270523  3.269381  3.268219  3.267033  3.265851  3.264617
# 181116  3.196180  3.195376  3.194512  3.193610  3.192671  3.191713  3.190692
# 181123  3.180150  3.179415  3.178641  3.177825  3.176974  3.176107  3.175183
# 181130  3.124374  3.123658  3.122894  3.122091  3.121237  3.120320  3.119348
# ...          ...       ...       ...       ...       ...       ...       ...
# 201218  1.453055  1.454247  1.455323  1.456268  1.457083  1.457789  1.458361
# 201225  1.437000  1.438184  1.439251  1.440186  1.440988  1.441676  1.442225
# 210101  1.433479  1.434472  1.435336  1.436089  1.436708  1.437214  1.437604
# 210108  1.653788  1.654900  1.655909  1.656799  1.657550  1.658185  1.658696
# 210115  1.610664  1.611686  1.612612  1.613413  1.614073  1.614611  1.615019
#
# [116 rows x 120 columns]

# %%
LIBOR_fwd.columns = [3 * x for x in LIBOR_fwd.columns]

# %%
SOFR_data = pd.read_excel(r'C:\Users\Richard\Desktop\CurrentTerm\ISYE 8900\CurveFrcst-Using-ManifoldLrn\Data\WklySOFR.xlsx', sheet_name=None)
#SOFR_data.keys()

# %%
for key in SOFR_data:
    if key == '181102':
        SOFR_zero = SOFR_data[key]['Zero Rate'].to_frame(name = key)
        SOFR_fwd = SOFR_data[key]['Forward Rate'].to_frame(name = key)
    else:
        SOFR_zero[key] = SOFR_data[key]['Zero Rate']
        SOFR_fwd[key] = SOFR_data[key]['Forward Rate']
SOFR_zero = SOFR_zero.T
SOFR_fwd = SOFR_fwd.T

# %%
SOFR_zero.columns = [3 * x for x in SOFR_zero.columns]
#SOFR_zero

# %%
SOFR_fwd.columns = [3 * x for x in SOFR_fwd.columns]
#SOFR_fwd

# %%
OIS_data = pd.read_excel(r'C:\Users\Richard\Desktop\CurrentTerm\ISYE 8900\CurveFrcst-Using-ManifoldLrn\Data\WklyOIS.xlsx', sheet_name=None)
#OIS_data.keys()

# %%
for key in OIS_data:
    if key == '191227':
        OIS_zero = OIS_data[key]['Zero Rate'].to_frame(name = key)
        OIS_fwd = OIS_data[key]['Forward Rate'].to_frame(name = key)
    else:
        OIS_zero[key] = OIS_data[key]['Zero Rate']
        OIS_fwd[key] = OIS_data[key]['Forward Rate']
OIS_zero = OIS_zero.T
OIS_fwd = OIS_fwd.T

# %%
OIS_zero.columns = [3 * x for x in OIS_zero.columns]
OIS_fwd.columns = [3 * x for x in OIS_fwd.columns]

# %% [markdown]
# ## Treasury yield curve loading and constructing

# %%
# nelson siegel swenson model: take four curve shape parameters and two hump date parameters, for each given tenor T
def NSS_zero_cstrct(T, beta0,beta1,beta2,beta3,tau1,tau2):
    # zero rate
    if T < 1/360: T = 1/360
    exp_tt1 = exp(-T/tau1)
    exp_tt2 = exp(-T/tau2)
    factor1 = (1 - exp_tt1) / (T / tau1)
    factor2 = factor1 - exp_tt1
    factor3 = (1 - exp_tt2) / (T / tau2) - exp_tt2
    res = beta0 + beta1*factor1 + beta2*factor2 + beta3*factor3
    return res

def NSS_fwd_cstrct(T, beta0,beta1,beta2,beta3,tau1,tau2):
    # forward rate
    if T < 1/365: T = 1/365
    exp_tt1 = exp(-T/tau1)
    exp_tt2 = exp(-T/tau2)
    return beta0 + beta1*exp_tt1 + beta2*exp_tt1*T/tau1 + beta3*exp_tt2*T/tau2

# %%
Treasury_data = pd.read_csv(r'C:\Users\Richard\Desktop\CurrentTerm\ISYE 8900\CurveFrcst-Using-ManifoldLrn\Data\feds200628_till210319.csv', index_col = 'Date', usecols = ['Date','BETA0','BETA1','BETA2','BETA3','TAU1','TAU2'], skiprows=9)
Treasury_data
# Out:
#                BETA0     BETA1       BETA2       BETA3      TAU1        TAU2
# Date
# 1961-06-14  3.917606 -1.277955   -1.949397    0.000000  0.339218 -999.990000
# 1961-06-15  3.978498 -1.257404   -2.247617    0.000000  0.325775 -999.990000
# 1961-06-16  3.984350 -1.429538   -1.885024    0.000000  0.348817 -999.990000
# 1961-06-19  4.004379 -0.723311   -3.310743    0.000000  0.282087 -999.990000
# 1961-06-20  3.985789 -0.900432   -2.844809    0.000000  0.310316 -999.990000
# ...              ...       ...         ...         ...       ...         ...
# 2021-03-15  2.911025 -2.663140 -141.404857  138.071667  2.370744    2.388815
# 2021-03-16  2.937549 -2.694755 -123.135938  119.804611  2.423192    2.445306
# 2021-03-17  4.580133 -4.309836   -5.558469   -4.297111  2.208964   21.082222
# 2021-03-18  5.726447 -5.466569   -6.339108   -7.513431  2.248462   19.957728
# 2021-03-19  5.922383 -5.638647   -6.582566   -8.128514  2.173055   19.186194
#
# [15593 rows x 6 columns]

# %%
Treasury_data = Treasury_data.fillna(method='bfill')
Treasury_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Index format transform

# %%
LIBOR_zero.index = pd.to_datetime(LIBOR_zero.index, format = '%y%m%d')
LIBOR_zero.index
# Out:
# DatetimeIndex(['2018-11-02', '2018-11-09', '2018-11-16', '2018-11-23',
#                '2018-11-30', '2018-12-07', '2018-12-14', '2018-12-21',
#                '2018-12-28', '2019-01-04',
#                ...
#                '2020-11-13', '2020-11-20', '2020-11-27', '2020-12-04',
#                '2020-12-11', '2020-12-18', '2020-12-25', '2021-01-01',
#                '2021-01-08', '2021-01-15'],
#               dtype='datetime64[ns]', length=116, freq=None)

# %%
LIBOR_fwd.index = pd.to_datetime(LIBOR_fwd.index, format = '%y%m%d')
SOFR_zero.index = pd.to_datetime(SOFR_zero.index, format = '%y%m%d')
SOFR_fwd.index = pd.to_datetime(SOFR_fwd.index, format = '%y%m%d')
OIS_zero.index = pd.to_datetime(OIS_zero.index, format = '%y%m%d')
OIS_fwd.index = pd.to_datetime(OIS_fwd.index, format = '%y%m%d')

# %%
Treasury_data.index = pd.to_datetime(Treasury_data.index, infer_datetime_format=True)
Treasury_data.index
# Out:
# DatetimeIndex(['1961-06-14', '1961-06-15', '1961-06-16', '1961-06-19',
#                '1961-06-20', '1961-06-21', '1961-06-22', '1961-06-23',
#                '1961-06-26', '1961-06-27',
#                ...
#                '2021-03-08', '2021-03-09', '2021-03-10', '2021-03-11',
#                '2021-03-12', '2021-03-15', '2021-03-16', '2021-03-17',
#                '2021-03-18', '2021-03-19'],
#               dtype='datetime64[ns]', name='Date', length=15593, freq=None)

# %%
Treasury_data = Treasury_data.loc[LIBOR_zero.index]
Treasury_data
# Out:
#                BETA0     BETA1        BETA2        BETA3      TAU1       TAU2
# 2018-11-02  3.659050 -1.657847    -0.000061    -1.523731  0.501227   2.650654
# 2018-11-09  3.554549 -1.658618    -0.000029    -1.258271  0.409790   2.610036
# 2018-11-16  3.529693 -1.477785     0.000023    -1.711106  0.424259   2.458331
# 2018-11-23  3.488041 -1.629262     0.000032    -1.712192  0.333062   2.336264
# 2018-11-30  3.554822 -1.116583  2566.759079 -2567.450262  1.996904   1.997857
# ...              ...       ...          ...          ...       ...        ...
# 2020-12-18  4.247042 -4.047089    -4.019393    -5.357007  2.987082  16.217983
# 2020-12-25  5.094908 -4.870351    -4.623375    -7.715492  3.111208  17.875437
# 2021-01-01  5.484257 -5.274936    -4.884348    -8.691812  3.254356  18.935793
# 2021-01-08  5.500143 -5.291998    -4.977467    -8.301650  2.911719  17.705727
# 2021-01-15  6.803752 -6.597345    -5.816416   -11.790081  3.169718  19.542711
#
# [116 rows x 6 columns]

# %%
Treasury_zero = pd.DataFrame(index = Treasury_data.index, columns = LIBOR_zero.columns)
Treasury_fwd = pd.DataFrame(index = Treasury_data.index, columns = LIBOR_fwd.columns)

# %%
for col in Treasury_zero.columns:
    Treasury_zero[col]=Treasury_data.apply(lambda x: NSS_zero_cstrct(col/12,x['BETA0'],x['BETA1'],x['BETA2'],x['BETA3'],x['TAU1'],x['TAU2']), axis=1)
    Treasury_fwd[col]=Treasury_data.apply(lambda x: NSS_fwd_cstrct(col/12,x['BETA0'],x['BETA1'],x['BETA2'],x['BETA3'],x['TAU1'],x['TAU2']), axis=1)

# %% [markdown]
# ## Visulization for cross-sectional

# %%
plt.figure(1,dpi=120)
l1, = plt.plot(Treasury_zero.columns, Treasury_zero.loc['2020-10-30'])
l2, = plt.plot(Treasury_fwd.columns, Treasury_fwd.loc['2020-10-30'])
plt.legend(handles=[l1,l2], labels = ['T zero','T fwd'], loc='best')
plt.title('Term Structure View on 2020-10-30')
# Out:
# Text(0.5, 1.0, 'Term Structure View on 2020-10-30')

# %%
OIS_zero.columns
# Out:
# Int64Index([  0,   3,   6,   9,  12,  15,  18,  21,  24,  27,
#             ...
#             330, 333, 336, 339, 342, 345, 348, 351, 354, 357],
#            dtype='int64', length=120)

# %%
plt.figure(2,dpi=120)
l1, = plt.plot(Treasury_zero.columns, Treasury_zero.loc['2020-10-30'].squeeze())
l2, = plt.plot(LIBOR_zero.columns, LIBOR_zero.loc['2020-10-30'].squeeze())
l3, = plt.plot(SOFR_zero.columns, SOFR_zero.loc['2020-10-30'].squeeze())
l4, = plt.plot(OIS_zero.columns, OIS_zero.loc['2020-10-30'].squeeze())
plt.legend(handles=[l1,l2,l3,l4], labels = ['T zero','LIBOR zero','SOFR zero','OIS zero'], loc='best')
plt.title('Term Structure View on 2020-10-30')
# Out:
# Text(0.5, 1.0, 'Term Structure View on 2020-10-30')

# %%
plt.figure(3,dpi=120)
l1, = plt.plot(Treasury_fwd.columns, Treasury_fwd.loc['2020-10-30'].squeeze())
l2, = plt.plot(LIBOR_fwd.columns, LIBOR_fwd.loc['2020-10-30'].squeeze())
l3, = plt.plot(SOFR_fwd.columns, SOFR_fwd.loc['2020-10-30'].squeeze())
l4, = plt.plot(OIS_fwd.columns, OIS_fwd.loc['2020-10-30'].squeeze())
plt.legend(handles=[l1,l2,l3,l4], labels = ['T fwd','LIBOR fwd','SOFR fwd','OIS fwd'], loc='best')
plt.title('Term Structure View on 2020-10-30')
# Out:
# Text(0.5, 1.0, 'Term Structure View on 2020-10-30')

# %% [markdown]
# ## Visulization for time series

# %%
plt.figure(7,dpi=120)
l1, = plt.plot(Treasury_zero.index, Treasury_zero[24])
l2, = plt.plot(LIBOR_zero.index, LIBOR_zero[24])
l3, = plt.plot(SOFR_zero.index, SOFR_zero[24])
plt.legend(handles=[l1,l2,l3], labels = ['T zero','LIBOR zero','SOFR zero'], loc='best')
plt.title('2yr Maturity Time Series View')
# Out:
# Text(0.5, 1.0, '2yr Maturity Time Series View')

# %%
plt.figure(8,dpi=120)
l1, = plt.plot(Treasury_zero.index, Treasury_zero[120])
l2, = plt.plot(LIBOR_zero.index, LIBOR_zero[120])
l3, = plt.plot(SOFR_zero.index, SOFR_zero[120])
plt.legend(handles=[l1,l2,l3], labels = ['T zero','LIBOR zero','SOFR zero'], loc='best')
plt.title('10yr Maturity Time Series View')
# Out:
# Text(0.5, 1.0, '10yr Maturity Time Series View')

# %%
plt.figure(9,dpi=120)
l1, = plt.plot(Treasury_zero.index, Treasury_zero[357])
l2, = plt.plot(LIBOR_zero.index, LIBOR_zero[357])
l3, = plt.plot(SOFR_zero.index, SOFR_zero[357])
plt.legend(handles=[l1,l2,l3], labels = ['T zero','LIBOR zero','SOFR zero'], loc='best')
plt.title('30yr Maturity Time Series View')
# Out:
# Text(0.5, 1.0, '30yr Maturity Time Series View')

# %% [markdown]
# ### Store clean dataset

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(r'C:\Users\Richard\Desktop\CurrentTerm\ISYE 8900\CurveFrcst-Using-ManifoldLrn\Data\LIBOR_clean.xlsx')
# Write each dataframe to a different worksheet
LIBOR_zero.to_excel(writer, sheet_name='zero')
LIBOR_fwd.to_excel(writer, sheet_name='forward')
# Close the Pandas Excel writer and output the Excel file.
writer.save()
writer.close()

# %%
with pd.ExcelWriter(r'C:\Users\Richard\Desktop\CurrentTerm\ISYE 8900\CurveFrcst-Using-ManifoldLrn\Data\SOFR_clean.xlsx') as writer:
    SOFR_zero.to_excel(writer, sheet_name='zero')
    SOFR_fwd.to_excel(writer, sheet_name='forward')

with pd.ExcelWriter(r'C:\Users\Richard\Desktop\CurrentTerm\ISYE 8900\CurveFrcst-Using-ManifoldLrn\Data\OIS_clean.xlsx') as writer:
    OIS_zero.to_excel(writer, sheet_name='zero')
    OIS_fwd.to_excel(writer, sheet_name='forward')
    
with pd.ExcelWriter(r'C:\Users\Richard\Desktop\CurrentTerm\ISYE 8900\CurveFrcst-Using-ManifoldLrn\Data\Treasury_clean.xlsx') as writer:
    Treasury_zero.to_excel(writer, sheet_name='zero')
    Treasury_fwd.to_excel(writer, sheet_name='forward')
